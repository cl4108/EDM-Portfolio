# %% [markdown]
# # Analysis Challenge Assignment 1
# Author: Chendanni Liu
#
# 1. criteria
# According to Alex, the school must be...
#
# safety -- (low crime)
# 1.	Sum of all crimes from Crime_2015 data set, from min to max, choose the top 10 city
# urban -- Big city life
# 1.	degree_urvanization = 1 (Large city) from "CollegeScorecardDataDictionary-09-12-2015"
# diversity -- Maria wants to study in a university with a diverse culture
# 1.	 CCBASIC (Carnegie Classification) = 15 (Large 4-year, primarily nonresidential (confers bachelorâ€™s degrees, FTE enrollment over 9,999, less than 25 percent of degree-seeking undergraduates live on campus and/or less than 50 percent attend full time) from "CollegeScorecardDataDictionary-09-12-2015"
# 2.	(minority_serving.historically_black, minority_serving.predominantly_black, minority_serving.annh, minority_serving.tribal, minority_serving.aanipi, minority_serving.hispanic, minority_serving.nant, =1) from "CollegeScorecardDataDictionary-09-12-2015"
# quality -- the school should offer a decent educational program
# 1.	degrees_awarded.highest from "CollegeScorecardDataDictionary-09-12-2015"  only degrees equal and above Bachelor’s degree(>=3)
# 2.	CURROPER (Flag for currently operating institution, 0=closed, 1=operating) from "CollegeScorecardDataDictionary-09-12-2015"
# 3.	ADM_RATE (Admission rate) pick the top 45 or less from "CollegeScorecardDataDictionary-09-12-2015"
#
#
# 2. import, clean, prepare, and merge data
# 2.1 college scorecard dataset

# %%
import pandas as pd

### Importing College scorecard dataset

# %%
Crime_data = pd.read_csv('Crime_2015.csv')

# %%
Crime_data
# Out:
#                                               MSA  ViolentCrime  Murder  Rape  \
# 0                              Abilene, TX M.S.A.         412.5     5.3  56.0
# 1                                Akron, OH M.S.A.         238.4     5.1  38.2
# 2                               Albany, GA M.S.A.         667.9     7.8  30.4
# 3                               Albany, OR M.S.A.         114.3     2.5  28.2
# 4                          Albuquerque, NM M.S.A.         792.6     6.1  63.8
# ..                                            ...           ...     ...   ...
# 373                   Guayama, Puerto Rico M.S.A.         251.6    11.4   6.3
# 374                  Mayaguez, Puerto Rico M.S.A.         237.5    11.5   5.2
# 375                     Ponce, Puerto Rico M.S.A.         231.4    18.0   5.0
# 376                San German, Puerto Rico M.S.A.          92.1     5.4   4.6
# 377  San Juan-Carolina-Caguas, Puerto Rico M.S.A.         262.0    20.6   4.9
#
# ...

# %%
Crime_data.isnull()
Crime_data.isnull().sum()
Crime_data=Crime_data.fillna(0)
Crime_data.isnull().sum()
# Out:
# MSA                  0
# ViolentCrime         0
# Murder               0
# Rape                 0
# Robbery              0
# AggravatedAssault    0
# PropertyCrime        0
# Burglary             0
# Theft                0
# MotorVehicleTheft    0
# State                0
# City                 0
# dtype: int64

# %%
#Selecting limited variables
Crime_data1 = Crime_data[['MSA','ViolentCrime','Murder','Rape','Robbery','AggravatedAssault','PropertyCrime','Burglary','Theft','MotorVehicleTheft']]
Crime_data1
# Out:
#                                               MSA  ViolentCrime  Murder  Rape  \
# 0                              Abilene, TX M.S.A.         412.5     5.3  56.0
# 1                                Akron, OH M.S.A.         238.4     5.1  38.2
# 2                               Albany, GA M.S.A.         667.9     7.8  30.4
# 3                               Albany, OR M.S.A.         114.3     2.5  28.2
# 4                          Albuquerque, NM M.S.A.         792.6     6.1  63.8
# ..                                            ...           ...     ...   ...
# 373                   Guayama, Puerto Rico M.S.A.         251.6    11.4   6.3
# 374                  Mayaguez, Puerto Rico M.S.A.         237.5    11.5   5.2
# 375                     Ponce, Puerto Rico M.S.A.         231.4    18.0   5.0
# 376                San German, Puerto Rico M.S.A.          92.1     5.4   4.6
# 377  San Juan-Carolina-Caguas, Puerto Rico M.S.A.         262.0    20.6   4.9
#
# ...

# %%
#define data frame
df = pd.DataFrame(Crime_data1)
df
# Out:
#                                               MSA  ViolentCrime  Murder  Rape  \
# 0                              Abilene, TX M.S.A.         412.5     5.3  56.0
# 1                                Akron, OH M.S.A.         238.4     5.1  38.2
# 2                               Albany, GA M.S.A.         667.9     7.8  30.4
# 3                               Albany, OR M.S.A.         114.3     2.5  28.2
# 4                          Albuquerque, NM M.S.A.         792.6     6.1  63.8
# ..                                            ...           ...     ...   ...
# 373                   Guayama, Puerto Rico M.S.A.         251.6    11.4   6.3
# 374                  Mayaguez, Puerto Rico M.S.A.         237.5    11.5   5.2
# 375                     Ponce, Puerto Rico M.S.A.         231.4    18.0   5.0
# 376                San German, Puerto Rico M.S.A.          92.1     5.4   4.6
# 377  San Juan-Carolina-Caguas, Puerto Rico M.S.A.         262.0    20.6   4.9
#
# ...

# %%
df.dtypes
# Out:
# MSA                   object
# ViolentCrime         float64
# Murder               float64
# Rape                 float64
# Robbery              float64
# AggravatedAssault    float64
# PropertyCrime        float64
# Burglary             float64
# Theft                float64
# MotorVehicleTheft    float64
# dtype: object

# %%
Crime_data1.info()
Crime_data1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378 entries, 0 to 377
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MSA                378 non-null    object
#  1   ViolentCrime       378 non-null    float64
#  2   Murder             378 non-null    float64
#  3   Rape               378 non-null    float64
#  4   Robbery            378 non-null    float64
#  5   AggravatedAssault  378 non-null    float64
#  6   PropertyCrime      378 non-null    float64
#  7   Burglary           378 non-null    float64
#  8   Theft              378 non-null    float64
#  9   MotorVehicleTheft  378 non-null    float64
# dtypes: float64(9), object(1)
# memory usage: 29.7+ KB
#                       MSA  ViolentCrime  Murder  Rape  Robbery  \
# 0      Abilene, TX M.S.A.         412.5     5.3  56.0     78.4
# 1        Akron, OH M.S.A.         238.4     5.1  38.2     75.2
# ...

# %%
df.loc[:,'Total_Crime'] = df.sum(numeric_only=True, axis=1)
df
# Out:
#                                               MSA  ViolentCrime  Murder  Rape  \
# 0                              Abilene, TX M.S.A.         412.5     5.3  56.0
# 1                                Akron, OH M.S.A.         238.4     5.1  38.2
# 2                               Albany, GA M.S.A.         667.9     7.8  30.4
# 3                               Albany, OR M.S.A.         114.3     2.5  28.2
# 4                          Albuquerque, NM M.S.A.         792.6     6.1  63.8
# ..                                            ...           ...     ...   ...
# 373                   Guayama, Puerto Rico M.S.A.         251.6    11.4   6.3
# 374                  Mayaguez, Puerto Rico M.S.A.         237.5    11.5   5.2
# 375                     Ponce, Puerto Rico M.S.A.         231.4    18.0   5.0
# 376                San German, Puerto Rico M.S.A.          92.1     5.4   4.6
# 377  San Juan-Carolina-Caguas, Puerto Rico M.S.A.         262.0    20.6   4.9
#
# ...

# %%
df.sort_values(by="Total_Crime").head(13)
# Out:
#                                               MSA  ViolentCrime  Murder  Rape  \
# 126                       Glens Falls, NY M.S.A.4         170.5     0.8  67.9
# 376                San German, Puerto Rico M.S.A.          92.1     5.4   4.6
# 91          Denver-Aurora-Lakewood, CO M.S.A.3, 4         362.3     3.8  63.6
# 371         Aguadilla-Isabela, Puerto Rico M.S.A.         108.7     4.8   3.5
# 149  Houston-The Woodlands-Sugar Land, TX M.S.A.3         566.6     6.9  37.3
# 244               Ogden-Clearfield, UT M.S.A.2, 3         157.6     2.3  52.1
# 373                   Guayama, Puerto Rico M.S.A.         251.6    11.4   6.3
# 375                     Ponce, Puerto Rico M.S.A.         231.4    18.0   5.0
# 125                         Gettysburg, PA M.S.A.         135.6     0.0  34.4
# 372                   Arecibo, Puerto Rico M.S.A.          99.3     6.9   2.7
# 335                       The Villages, FL M.S.A.         232.1     0.8  14.9
# ...
